# %% [markdown]
# #Filtros para fases de datos
# Cecilia Ibarrondo Florin

# %%
import pandas as pd
marvel = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/marvel_clean.csv")
marvel.head(11)
# Out:
#               Title         Distributor        ReleaseDateUS     Budget  \
# 0   Howard the Duck  Universal Pictures  1986-08-01 00:00:00   37000000
# 1             Blade     New Line Cinema  1998-08-21 00:00:00   45000000
# 2             X-Men    20th Century Fox  2000-07-14 00:00:00   75000000
# 3          Blade II     New Line Cinema  2002-03-22 00:00:00   54000000
# 4        Spider-Man       Sony Pictures  2002-05-03 00:00:00  139000000
# 5         Daredevil    20th Century Fox  2003-02-14 00:00:00   78000000
# 6                X2    20th Century Fox  2003-05-02 00:00:00  110000000
# 7              Hulk  Universal Pictures  2003-06-20 00:00:00  137000000
# 8      The Punisher     Lionsgate Films  2004-04-16 00:00:00   33000000
# 9      Spider-Man 2       Sony Pictures  2004-06-30 00:00:00  200000000
# 10   Blade: Trinity     New Line Cinema  2004-12-08 00:00:00   65000000
#
#     OpeningWeekendNorthAmerica  NorthAmerica  OtherTerritories  Worldwide
# ...

# %%
marvel.columns
# Out:
# Index(['Title', 'Distributor', 'ReleaseDateUS', 'Budget',
#        'OpeningWeekendNorthAmerica', 'NorthAmerica', 'OtherTerritories',
#        'Worldwide'],
#       dtype='object')

# %%
marvel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Title                       64 non-null     object
#  1   Distributor                 64 non-null     object
#  2   ReleaseDateUS               64 non-null     object
#  3   Budget                      64 non-null     int64
#  4   OpeningWeekendNorthAmerica  64 non-null     int64
#  5   NorthAmerica                64 non-null     int64
#  6   OtherTerritories            64 non-null     int64
#  7   Worldwide                   64 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 4.1+ KB

# %%
marvel = marvel.drop(columns=["NorthAmerica", "OtherTerritories"])
marvel.head()
# Out:
#              Title         Distributor        ReleaseDateUS     Budget  \
# 0  Howard the Duck  Universal Pictures  1986-08-01 00:00:00   37000000
# 1            Blade     New Line Cinema  1998-08-21 00:00:00   45000000
# 2            X-Men    20th Century Fox  2000-07-14 00:00:00   75000000
# 3         Blade II     New Line Cinema  2002-03-22 00:00:00   54000000
# 4       Spider-Man       Sony Pictures  2002-05-03 00:00:00  139000000
#
#    OpeningWeekendNorthAmerica  Worldwide
# 0                     5070136   37962774
# 1                    17073856  131183530
# 2                    54471475  296339527
# 3                    32528016  155010032
# 4                   114844116  821708551

# %%
marvel.rename(columns= {"OpeningWeekendNorthAmerica" : "Opening"}, inplace=True)

# %%
marvel
# Out:
#                                         Title  \
# 0                             Howard the Duck
# 1                                       Blade
# 2                                       X-Men
# 3                                    Blade II
# 4                                  Spider-Man
# ..                                        ...
# 59                                Black Widow
# 60  Shang-Chi and the Legend of the Ten Rings
# 61                Venom: Let There Be Carnage
# 62                                   Eternals
# 63                    Spider-Man: No Way Home
#
#                             Distributor        ReleaseDateUS     Budget  \
# 0                    Universal Pictures  1986-08-01 00:00:00   37000000
# 1                       New Line Cinema  1998-08-21 00:00:00   45000000
# 2                      20th Century Fox  2000-07-14 00:00:00   75000000
# 3                       New Line Cinema  2002-03-22 00:00:00   54000000
# ...

# %%
spidey = marvel.iloc[4]
spidey.to_frame().T["Distributor"]
# Out:
# 4    Sony Pictures
# Name: Distributor, dtype: object

# %%
spidey.iloc[1]
# Out:
# 'Sony Pictures'

# %%
type(spidey)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd

# Crear el DataFrame
data = {
    'Columna1': [10, 20, 30],
    'Columna2': ['A', 'B', 'C'],
    'Columna3': [1.5, 2.5, 3.5],
    'Columna4': [True, False, True],
    'Columna5': ['X', 'Y', 'Z']
}

df = pd.DataFrame(data)

# Mostrar el DataFrame
print(df)
df.T
# Out:
#    Columna1 Columna2  Columna3  Columna4 Columna5
# 0        10        A       1.5      True        X
# 1        20        B       2.5     False        Y
# 2        30        C       3.5      True        Z
#              0      1     2
# Columna1    10     20    30
# Columna2     A      B     C
# Columna3   1.5    2.5   3.5
# Columna4  True  False  True
# Columna5     X      Y     Z

# %%
#De acuerdo al Buget, vamos a ver qué películas tienen más que spidey
marvel_budget = marvel[marvel["Budget"]>= 139000000]

# %%
marvel_ budget = marvel_budget.sort_values(by="Budget", ascending=False)
# Out:
#                                         Title  \
# 55                          Avengers: Endgame
# 49                     Avengers: Infinity War
# 15                               Spider-Man 3
# 32                   The Amazing Spider-Man 2
# 40                 Captain America: Civil War
# 36                    Avengers: Age of Ultron
# 27                     The Amazing Spider-Man
# 26                               The Avengers
# 13                      X-Men: The Last Stand
# 28                                 Iron Man 3
# 9                                Spider-Man 2
# 33                 X-Men: Days of Future Past
# 63                    Spider-Man: No Way Home
# 48                              Black Panther
# 21                                 Iron Man 2
# 56                               Dark Phoenix
# 59                                Black Widow
# 62                                   Eternals
# 44             Guardians of the Galaxy Vol. 2
# ...

# %%
marvel_budget.groupby("Opening").max()
# Out:
#                                                Title  \
# Opening
# 32828348                                Dark Phoenix
# 55101604                          X-Men: First Class
# 55414050                         The Incredible Hulk
# 56215889                                  Big Hero 6
# 62004688                      The Amazing Spider-Man
# 65058524          Captain America: The First Avenger
# 65723338                                        Thor
# 65769562                           X-Men: Apocalypse
# 75388688   Shang-Chi and the Legend of the Ten Rings
# 75812205                        Ant-Man and the Wasp
# 80366312                                 Black Widow
# 85021497                                    Eternals
# 85058003                    X-Men Origins: Wolverine
# 85058311                              Doctor Strange
# 85737841                        Thor: The Dark World
# 88156227                                Spider-Man 2
# ...
